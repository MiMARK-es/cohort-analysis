# %%
from ethnicity_utils import get_gdc_file_ids, download_xml_files, load_race_data

# %%
ids = get_gdc_file_ids()

# %%
len(ids)
# Out:
# 605

# %%
download_xml_files(ids, "/data/expression/xml_files/")
# Out:
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-B5-A0JT.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-B5-A11S.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-BG-A0MT.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-E6-A1LX.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-D1-A0ZQ.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-BS-A0VI.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-BG-A0M3.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-AJ-A3NF.xml
# ...
# Downloaded: nationwidechildrens.org_omf.TCGA-EY-A214.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-EO-A3L0.xml
# ...
# Downloaded: nationwidechildrens.org_omf.TCGA-BG-A220.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-AJ-A3EJ.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-BK-A13C.xml
# ...
# Downloaded: nationwidechildrens.org_omf.TCGA-AX-A1CP.xml
# ...
# Downloaded: nationwidechildrens.org_clinical.TCGA-D1-A2G7.xml
# ...
